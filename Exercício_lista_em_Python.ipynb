# %% [markdown]
# <a href="https://colab.research.google.com/github/ThatiFlowers/Estudos-em-Python/blob/main/Exerc%C3%ADcio_lista_em_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Lista fornecida
lista = [16, 14, 63, 65, 17, 99, 70, 11, 20, 48, 79, 32, 17, 89, 12, 25, 66]

# Calculando os dados solicitados
tam = len(lista)
maior = max(lista)
menor = min(lista)
soma = sum(lista)

# Exibindo o resultado
print(f"A lista possui {tam} números em que o maior número é {maior} e o menor número é {menor}. A soma dos valores presentes nela é igual a {soma}.")
# Out:
# A lista possui 17 números em que o maior número é 99 e o menor número é 11. A soma dos valores presentes nela é igual a 743.
